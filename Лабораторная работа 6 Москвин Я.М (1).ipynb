# %%
import seaborn as sns
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sqlite3
import os

# %%
data = [{'name': 'Anton', 'gift': 'guitar', 'price': '100', 'buystatus': '0'},
        {'name': 'Andrew', 'gift': 'ball', 'price': '20', 'buystatus': '1'},
        {'name': 'Sergey', 'gift': 'ping-pong', 'price': '10', 'buystatus': '1'},
        {'name': 'Victor', 'gift': 'cups', 'price': '30', 'buystatus': '1'},
        {'name': 'Mikhail', 'gift': 'dishes', 'price': '30', 'buystatus': '1'},
        {'name': 'Daria', 'gift': 'socks', 'price': '50', 'buystatus': '0'},
        {'name': 'Elena', 'gift': 'pullover', 'price': '60', 'buystatus': '0'},
        {'name': 'Kristina', 'gift': 'delicious', 'price': '25', 'buystatus': '0'},
        {'name': 'Yaroslav', 'gift': 'shoes', 'price': '150', 'buystatus': '0'},
        {'name': 'Alex', 'gift': 'stick', 'price': '250', 'buystatus': '0'},]

# %%
connection  = sqlite3.connect('NewYearGifts.db')

# %%
pddata = pd.DataFrame(data=data)
# Out:
#        name       gift price buystatus
# 0     Anton     guitar   100         0
# 1    Andrew       ball    20         1
# 2    Sergey  ping-pong    10         1
# 3    Victor       cups    30         1
# 4   Mikhail     dishes    30         1
# 5     Daria      socks    50         0
# 6     Elena   pullover    60         0
# 7  Kristina  delicious    25         0
# 8  Yaroslav      shoes   150         0
# 9      Alex      stick   250         0

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})

# %%
df = df.reindex(columns=['C','A' ])
df
# Out:
#    C  A
# 0  7  1
# 1  8  2
# 2  9  3

# %%
pddata.to_sql('gifts',  connection, index = True, if_exists='replace')
# Out:
# 10

# %%
sql = """
    SELECT * from gifts;
    """
#проверяем заполнение БД
pd.read_sql(sql, connection)
# Out:
#    index      name       gift price buystatus
# 0      0     Anton     guitar   100         0
# 1      1    Andrew       ball    20         1
# 2      2    Sergey  ping-pong    10         1
# 3      3    Victor       cups    30         1
# 4      4   Mikhail     dishes    30         1
# 5      5     Daria      socks    50         0
# 6      6     Elena   pullover    60         0
# 7      7  Kristina  delicious    25         0
# 8      8  Yaroslav      shoes   150         0
# 9      9      Alex      stick   250         0
